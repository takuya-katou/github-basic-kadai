# %%
class Human:
    def __init__(self):
        self.name = ""
        self.age = ""

    def printinfo(self, name, age):
        self.name = name
        self.age = age
        print(self.name)
        print(self.age)

info = Human()
info.printinfo("jiro", 8)
# Out:
# jiro
# 8
