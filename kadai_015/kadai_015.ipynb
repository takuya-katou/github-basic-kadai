# %%
class Human:
    def __init__(self):
        self.name = "jiro"
        self.age = "5"

    def printinfo(self):
        print(self.name, self.age)

info = Human()

info.printinfo()
# Out:
# jiro 5
